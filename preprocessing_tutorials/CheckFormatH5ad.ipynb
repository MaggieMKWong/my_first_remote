# %% [markdown]
# <a href="https://colab.research.google.com/github/MaggieMKWong/my_first_remote/blob/main/preprocessing_tutorials/CheckFormatH5ad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This script allows you to check if your query data conforms to the requirements of ArchMap. Please upload your query data and run the cells below. If you obtain an error, please check our Documentation [here](https://archmap-docu.readthedocs.io/en/latest/faqs/index.html) for more info on how to troubleshoot your error. If this does not help, please reach out to us using our contact form on the website.

# %%
data_path = "test_data/HLCA_delorey.h5ad"

# %%
# !pip install scanpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 71.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
import scanpy as sc
import tempfile

def check_data(data_path):
  try:
      query_adata_raw = sc.read(data_path)
      print("Data successfully loaded.")
  except Exception as e:
      raise RuntimeError(f"Error message: {e}, There is likely an issue with the way your data (anndata object) is formatted upon upload. Please reach out to ArchMap (archmap.bio@gmail.com) with a screenshot of this error and we can help resolve this.")


      if "batch" not in query_adata_raw.obs.columns:
        raise ValueError("Batch key information not specified. Please make sure your batch key is labelled 'batch' in your query data. Please see ArchMap Docs for more info")

      if query_adata_raw.n_obs>200000:
        raise ValueError(f"The number of cells in the query is over the limit of 200 000 cells. Please divide your data in batches and map the batches separately.")

      try:
        temp_query = tempfile.NamedTemporaryFile(suffix=".h5ad")
        query_adata_raw.write_h5ad(temp_query.name)

        print("All checks completed. You query conforms to all requirements :)")
      except ValueError as e:
        if "is also used by a column whose values are different" in str(e):
            raise ValueError(f"Error message: {e}, Please check your anndata object for columns in .obs and .var that have matching names and delete duplicates") from e
        else:
            raise ValueError(f"Error message: {e}. There is likely an issue with the way your data (anndata object) is formatted upon upload. Please reach out to ArchMap (archmap.bio@gmail.com) with a screenshot of this error and we can help resolve this.")

# %%
check_data(data_path)
